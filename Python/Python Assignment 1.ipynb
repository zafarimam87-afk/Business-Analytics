# %% [markdown]
# # Instructions
#
# Add your code as indicated in each cell. You can add cells if you want to test or experiment with your code. However, do not alter/delete cells that state **"DO NOT CHANGE OR DELETE THIS CELL".**
#
# Before you turn this in, make sure everything runs as expected. Start from the very first cell, Run them one by one, including the cell that computes your total score for this assignment. If you cannot program a specific question and get an error, still run its cell and go to the next cell and keep running it.
#
# All work must be your own. I use a plagiarism check for coding. Copying and pasting code is not allowed. If you attempt to fake passing the tests, you will receive a 0 on the assignment, and it will be considered an ethical violation.
#
# You will need to submit three things:
# 1.   The link to your Google Colab notebook file: Submit the link to your notebook file. To do so, click Share on the top right-hand side. Then a box will pop-up. You need to change "restricted" to "anyone with the link." Then, copy the link and paste it as a comment when submitting the assignment.
# 2. The .pynb version of your notebook file: Download the Colab file as ipynb. To do so, go to file > Download > Download .ipynb.
# 3.   The pdf version of your notebook file: Download the same file as pdf. To do so, right click on any white space located at the top of this file. A drop down menu will pop up, select print page, then instead of printing, save the file as pdf.

# %% [markdown]
# # Run Cell Below to Store Your Assignment Score

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

score = {}

# %% [markdown]
# # Question 1
#
# Create a variable named `x` and assign `15` to it
#
# Create a variable named `y` and assign `456` to it
#
# Create a variable named `remainder` and assign the remainder you obtain by dividing `y` by `x`
#
# **Note:** Your code goes in the below cell. Do not type the remainder manually.
# Recall that remainder is the number that is left after division. For instance, the number that is left after dividing 303 by 10 is 3

# %%
###
### YOUR CODE HERE
x = 15
y = 456
remainder = y % x
###

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

print(x, y, remainder)
# Out:
# 15 456 6

# %% [markdown]
# **Question 1 test case is below**

# %%
score = {}

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

try:
    if remainder == 6:
        score['question 1'] = 'pass'
    else:
        score['question 1'] = 'fail'
except:
    score['question 1'] = 'fail'
score
# Out:
# {'question 1': 'pass'}

# %% [markdown]
# # Question 2
#
# Create a variable named `sent_1` and assign `"I love business analytics"` to it.
#
# Create a variable named `last_three_letters` and assign the last three letters of the `sent_1` variable. Note that you need to extract the last three letters using Python. You are not allowed to manually type 'ics'
#
# **Note:** Your code goes in the below cell. Do not hard code it. In other words, do not type just  'ics'. You have to program it using Python functions

# %%
###
### YOUR CODE HERE
sent_1 = "I love business analytics"
last_three_letters = sent_1[-3:]
print(last_three_letters)
###
# Out:
# ics

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

print(last_three_letters)
# Out:
# ics

# %%
score = {}

# %% [markdown]
# **Question 2 test case is below**

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

try:
    if last_three_letters == 'ics':
        score['question 2'] = 'pass'
    else:
        score['question 2'] = 'fail'
except:
    score['question 2'] = 'fail'
score
# Out:
# {'question 1': 'pass', 'question 2': 'pass'}

# %% [markdown]
# # Question 3
#
# Create a variable named `text_1` and assign `'I am from PA, and I study analytics'` to it
#
# Create a variable named `reversed_text` and assign the reversed version of the `text_1` variable. Note that you need to reverse the `text_1` variable using Python. You are not allowed to manually type the result
#
# **Note:** Your code goes in the below cell. Do not hard code it. In other words, do not manually type result. You have to program it using Python functions.

# %%
###
### YOUR CODE HERE
text_1 = 'I am from PA, and I study analytics'
reversed_text = text_1[::-1]
print(reversed_text)

###
# Out:
# scitylana yduts I dna ,AP morf ma I

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

print(reversed_text)
# Out:
# scitylana yduts I dna ,AP morf ma I

# %% [markdown]
# **Question 3 test case is below**

# %%
score = {}

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

try:
    if reversed_text == 'scitylana yduts I dna ,AP morf ma I':
        score['question 3'] = 'pass'
    else:
        score['question 3'] = 'fail'
except:
    score['question 3'] = 'fail'
score
# Out:
# {'question 3': 'pass'}

# %% [markdown]
# # Question 4
#
# Create a variable named `first_text` and assign `'Eagles are my fav team'`
#
# Create a variable named `second_text` and assign `'Giants are my fav team'`
#
# Create a variable named `total_length` and assign the sum of the total characters (letters) occuring in the `first_text` and `second_text` variables.
#
# **Note:** Your code goes in the below cell. Do not hard code it.
# In other words, do not manually count the number of characters in `first_text` and `second_text` variables and then manually type it. You have to program it using Python functions.

# %%
###
### YOUR CODE HERE
first_text = 'Eagles are my fav team'
second_text = 'Giants are my fav team'
total_length = len(first_text) + len(second_text)
print(total_length)


###
# Out:
# 44

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

print(total_length)
# Out:
# 44

# %% [markdown]
# **Question 4 test case is below**

# %%
score = {}

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

try:
    if total_length  == 44:
        score['question 4'] = 'pass'
    else:
        score['question 4'] = 'fail'
except:
    score['question 4'] = 'fail'
score
# Out:
# {'question 4': 'pass'}

# %% [markdown]
# # Question 5
#
# Create a variable named `sentence` and assign `'I love The Philadelphia Eagles'` to it
#
# Create a variable named `new_sentence` and assign the sentence variable in all capital letters without any white spaces. For example, I love you should be ILOVEYOU
#
# **Note:** Your code goes in the below cell. Do not hard code it. In other words, do not manually remove the white spaces and make the sentence all capital. You have to program it using Python functions.

# %%
###
### YOUR CODE HERE
sentence = 'I love The Philadelphia Eagles'
new_sentence = sentence.upper().replace(" ", "")
print(new_sentence)


###
# Out:
# ILOVETHEPHILADELPHIAEAGLES

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

print(new_sentence)
# Out:
# ILOVETHEPHILADELPHIAEAGLES

# %% [markdown]
# **Question 5 test case is below**

# %%
score = {}

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

try:
    if new_sentence  == 'ILOVETHEPHILADELPHIAEAGLES':
        score['question 5'] = 'pass'
    else:
        score['question 5'] = 'fail'
except:
    score['question 5'] = 'fail'
score
# Out:
# {'question 5': 'pass'}

# %% [markdown]
# # Question 6
#
# Create a variable named `number_float` and assign `6.8` to it
#
# Create a variable named `number_int` and assign the integer version of the  `number_float` variable.
#
# Note: Your code goes in the below cell. Do not hard code it.
# In other words, do not manually make the number integar and manually assign it to `number_int`. You have to program it using Python functions.

# %%
###
### YOUR CODE HERE
number_float = 6.8
number_int = int(number_float)
print(number_float)
###
# Out:
# 6.8

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

print(number_int)
# Out:
# 6

# %% [markdown]
# **Question 6 test case is below**

# %%
score = {}

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

try:
    if number_int == 6:
        score['question 6'] = 'pass'
    else:
        score['question 6'] = 'fail'
except:
    score['question 6'] = 'fail'
score
# Out:
# {'question 6': 'pass'}

# %% [markdown]
# # Question 7
#
# Create a variable named `string_1` and assign `'Data anAlytics is Expected to be IN high demand iN the future'`
#
# Create a variable named `string_2` and assign `In` to it. (hint: You may need to change the v ariables to all upper or lower case)
#
# Create another variable called `n_of_occurances`. Find how many times `string_2` occurs in `string_1`. Save this number to the `n_of_occurances` variable
#
# Note: Your code goes in the below cell. Do not hard code it.
# In other words, You have to program it using Python functions.

# %%
###
### YOUR CODE HERE
string_1 = 'Data anAlytics is Expected to be IN high demand iN the future'
string_2 = 'In'
string_1_lower = string_1.lower()
string_2_lower = string_2.lower()
n_of_occurances = string_1_lower.count(string_2_lower)
print(n_of_occurances)


###
# Out:
# 2

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

print(n_of_occurances)
# Out:
# 2

# %%
score = {}

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

try:
    if n_of_occurances == 2:
        score['question 7'] = 'pass'
    else:
        score['question 7'] = 'fail'
except:
    score['question 7'] = 'fail'
score
# Out:
# {'question 7': 'pass'}

# %% [markdown]
# # Question 8
#
# Create a variable named `list_1` and assign `[2, 2, 100, 100, 5, 4, 6, 3, 3]`
#
# Write python code to remove the duplicates in `list_1`. Create a variable named `list_2` and assign the values in `list_1` without any duplicates. list_2 should be a list type - not a set
#
# Note: Your code goes in the below cell. Do not hard code it.
# In other words, You have to program it using Python functions.

# %%
###
### YOUR CODE HERE
list_1 = [2, 2, 100, 100, 5, 4, 6, 3, 3]
list_2 = list(dict.fromkeys(list_1))
print(list_2)


###
# Out:
# [2, 100, 5, 4, 6, 3]

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

print(list_2)
# Out:
# [2, 100, 5, 4, 6, 3]

# %%
score = {}

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

try:
  list_2.sort()
  if list_2 == [2, 3, 4, 5, 6, 100]:
    score['question 8'] = 'pass'
  else:
    score['question 8'] = 'fail'
except:
  score['question 8'] = 'fail'
score
# Out:
# {'question 8': 'pass'}

# %% [markdown]
# # Total Score
# Run the cell below without changing anything to see your total grade

# %%
### RUN THIS CELL
### DO NOT CHANGE OR DELETE THIS CELL
### CHANGING OR DELETING THIS CELL MAY IMPACT YOUR GRADE
### AGAIN - DO NOT CHANGE OR DELETE THIS CELL

total_score = 0
for i in list(score.values()):
    if i=='pass':
        total_score = total_score + 12.5
print('your total score is: ', round(total_score))
print(score)
# Out:
# your total score is:  12
# {'question 8': 'pass'}
